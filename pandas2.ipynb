# %% [markdown]
# <a href="https://colab.research.google.com/github/zawztun/Boiler-plate-test/blob/master/pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas.core.frame import DataFrame
DataFrame
import numpy as np
amz = pd.read_csv("./amazon_prime_titles.csv")
amz
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
row, col = amz.shape
col
# Out:
# 12

# %%
row
# Out:
# 9668

# %%
amz.head(3)
# Out:
#   show_id   type                 title      director  \
# 0      s1  Movie   The Grand Seduction  Don McKellar
# 1      s2  Movie  Take Care Good Night  Girish Joshi
# 2      s3  Movie  Secrets of Deception   Josh Webber
#
#                                                 cast        country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...  United States
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# ...

# %%
amz.tail(5)
# Out:
#      show_id     type                    title         director  \
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast country date_added  \
# 9663                           Leo Gorcey, Bobby Jordan     NaN        NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...     NaN        NaN
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...     NaN        NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...     NaN        NaN
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...     NaN        NaN
#
#       release_year rating   duration                listed_in  \
# 9663          1940     7+     60 min                   Comedy
# ...

# %%
#row#2 to 5 / amx[2:5] // 2 to 4 print not including 5

# %%
amz[2:5]
# Out:
#   show_id   type                 title        director  \
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014    NaN   69 min              Documentary
# 4  March 30, 2021          1989    NaN   45 min           Drama, Fantasy
#
#                                          description
# 2  After a man discovers his wife is cheating on ...
# 3  Pink breaks the mold once again, bringing her ...
# ...

# %%
amz.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
amz.country
# Out:
# 0               Canada
# 1                India
# 2        United States
# 3        United States
# 4       United Kingdom
#              ...
# 9663               NaN
# 9664               NaN
# 9665               NaN
# 9666               NaN
# 9667               NaN
# Name: country, Length: 9668, dtype: object

# %%
amz[['type', 'country', 'listed_in']]
# Out:
#          type         country                listed_in
# 0       Movie          Canada            Comedy, Drama
# 1       Movie           India     Drama, International
# 2       Movie   United States  Action, Drama, Suspense
# 3       Movie   United States              Documentary
# 4       Movie  United Kingdom           Drama, Fantasy
# ...       ...             ...                      ...
# 9663    Movie             NaN                   Comedy
# 9664  TV Show             NaN                 TV Shows
# 9665    Movie             NaN                   Action
# 9666  TV Show             NaN            Drama, Sports
# 9667    Movie             NaN  Action, Drama, Suspense
#
# [9668 rows x 3 columns]

# %%
#amz["release_year"] = pd.to_datetime(amz["release_year"])

# %%
amz["release_year"].min()
# Out:
# Timestamp('1970-01-01 00:00:00.000001920')

# %%
amz["release_year"].max()
# Out:
# Timestamp('1970-01-01 00:00:00.000002021')

# %%
# amz.groupby("country").count()["show id"].sort_values(ascending= False)
amz["country"].value_counts()
# Out:
# United States                            253
# India                                    229
# United Kingdom                            28
# Canada                                    16
# United Kingdom, United States             12
#                                         ...
# United States, Germany, Brazil, Italy      1
# South Africa                               1
# Australia, United States, Germany          1
# Germany, Austria, United States            1
# Italy, Spain                               1
# Name: country, Length: 86, dtype: int64

# %%
# amz.groupby(["country"] count()[["show id"]].sort_values(ascending= False)

# %%
amz["date_added"]
# Out:
# 0       March 30, 2021
# 1       March 30, 2021
# 2       March 30, 2021
# 3       March 30, 2021
# 4       March 30, 2021
#              ...
# 9663               NaN
# 9664               NaN
# 9665               NaN
# 9666               NaN
# 9667               NaN
# Name: date_added, Length: 9668, dtype: object

# %%
#3
# date_amz = amz.dropna(subset= ["date_added"]).copy()
# date_amz["year_added"] = date_amz["date_added"].str.split(" , " , expand = True)[1].astype(int)

# %%
#4
movie_amz = amz[amz["type"]=="Movie"].copy()
movie_amz[" runtime_minutes"] = movie_amz["duration"].str.split(expand= True)[0].astype(int)
movie_amz
# Out:
#      show_id   type                 title  \
# 0         s1  Movie   The Grand Seduction
# 1         s2  Movie  Take Care Good Night
# 2         s3  Movie  Secrets of Deception
# 3         s4  Movie    Pink: Staying True
# 4         s5  Movie         Monster Maker
# ...      ...    ...                   ...
# 9660   s9661  Movie    The Man in the Hat
# 9662   s9663  Movie                 River
# 9663   s9664  Movie   Pride Of The Bowery
# 9665   s9666  Movie               Outpost
# 9667   s9668  Movie           Harry Brown
#
#                                  director  \
# 0                            Don McKellar
# 1                            Girish Joshi
# 2                             Josh Webber
# 3                          Sonia Anderson
# 4                            Giles Foster
# ...                                   ...
# 9660  John-Paul Davidson, Stephen Warbeck
# 9662                           Emily Skye
# 9663                      Joseph H. Lewis
# ...

# %%
movie_amz[" runtime_minutes"] = pd
